# %%
import warnings

import cmasher as cmr
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from highlight_text import ax_text
from statsbombpy import sb
import pandas as pd

from mplsoccer import Pitch, VerticalPitch, add_image, FontManager, Sbopen

# %%
#list all the competitions from statsbomb
sb.competitions()
# Out:
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# 12              16         37                    Europe
# 13              16         44                    Europe
# 14              16         76                    Europe
# 15              37         90                   England
# ...

# %%
#added it to df variable, choose the desirable competitions and season
df = sb.matches(competition_id=43, season_id=3)
#events = sb.

# %%
pd.set_option('display.max_rows', None)
df
# Out:
#     match_id  match_date      kick_off                     competition season  \
# 0       7548  2018-06-22  14:00:00.000  International - FIFA World Cup   2018
# 1       7578  2018-06-15  14:00:00.000  International - FIFA World Cup   2018
# 2       7553  2018-06-23  17:00:00.000  International - FIFA World Cup   2018
# 3       7544  2018-06-20  17:00:00.000  International - FIFA World Cup   2018
# 4       7536  2018-06-18  17:00:00.000  International - FIFA World Cup   2018
# 5       7555  2018-06-24  20:00:00.000  International - FIFA World Cup   2018
# 6       7546  2018-06-21  17:00:00.000  International - FIFA World Cup   2018
# 7       7539  2018-06-19  17:00:00.000  International - FIFA World Cup   2018
# 8       7538  2018-06-18  14:00:00.000  International - FIFA World Cup   2018
# 9       7576  2018-06-15  20:00:00.000  International - FIFA World Cup   2018
# 10      7565  2018-06-27  20:00:00.000  International - FIFA World Cup   2018
# ...

# %%
df = sb.events(match_id=7584)

# %%
pd.set_option('display.max_rows', 5)
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#      ball_receipt_outcome ball_recovery_recovery_failure block_offensive  \
# 0                     NaN                            NaN             NaN
# 1                     NaN                            NaN             NaN
# ...                   ...                            ...             ...
# 3713                  NaN                            NaN             NaN
# 3714                  NaN                            NaN             NaN
#
#      carry_end_location counterpress dribble_nutmeg dribble_outcome  \
# 0                   NaN          NaN            NaN             NaN
# 1                   NaN          NaN            NaN             NaN
# ...                 ...          ...            ...             ...
# 3713                NaN          NaN            NaN             NaN
# 3714                NaN          NaN            NaN             NaN
#
#      dribble_overrun duel_outcome duel_type  duration  \
# 0                NaN          NaN       NaN       0.0
# ...

# %%
import json
tactics = df['tactics'].dropna()
tactics = tactics.to_json('tactics.json',orient='columns', force_ascii = False)
# tactics = pd.read_json(tactics)
# tactics
# dfx = pd.read_json(tactics, orient='index')
# line = []
# for line in dfx['lineup']:
#      print(line)

# %%
with open('tactics.json',  encoding="utf8") as f:
    d = json.load(f)
d
# Out:
# {'0': {'formation': 541,
#   'lineup': [{'player': {'id': 3509, 'name': 'Thibaut Courtois'},
#     'position': {'id': 1, 'name': 'Goalkeeper'},
#     'jersey_number': 1},
#    {'player': {'id': 20005, 'name': 'Toby Alderweireld'},
#     'position': {'id': 3, 'name': 'Right Center Back'},
#     'jersey_number': 2},
#    {'player': {'id': 3101, 'name': 'Vincent Kompany'},
#     'position': {'id': 4, 'name': 'Center Back'},
#     'jersey_number': 4},
#    {'player': {'id': 3077, 'name': 'Jan Vertonghen'},
#     'position': {'id': 5, 'name': 'Left Center Back'},
#     'jersey_number': 5},
#    {'player': {'id': 3176, 'name': 'Thomas Meunier'},
#     'position': {'id': 7, 'name': 'Right Wing Back'},
#     'jersey_number': 15},
#    {'player': {'id': 5633, 'name': 'Yannick Ferreira Carrasco'},
#     'position': {'id': 8, 'name': 'Left Wing Back'},
#     'jersey_number': 11},
#    {'player': {'id': 3089, 'name': 'Kevin De Bruyne'},
# ...

# %%
pd.read_json('tactics.json').head()
# Out:
#                                                            0  \
# formation                                                541
# lineup     [{'player': {'id': 3509, 'name': 'Thibaut Cour...
#
#                                                            1
# formation                                               4231
# lineup     [{'player': {'id': 3175, 'name': 'Eiji Kawashi...

# %%
with open('tactics.json', encoding="utf8") as datafile:
    for line in datafile:
        data = json.loads(line)
    ww = pd.DataFrame(data)
ww.head()
# Out:
#                                                            0  \
# formation                                                541
# lineup     [{'player': {'id': 3509, 'name': 'Thibaut Cour...
#
#                                                            1
# formation                                               4231
# lineup     [{'player': {'id': 3175, 'name': 'Eiji Kawashi...

# %%
df_tactics = pd.read_json('tactics.json', encoding='utf8')
# dfx = pd.DataFrame(df.features.values.tolist())['player']
# df.features.values
df_tactics.columns
df_tactics = df_tactics.rename(columns={'0': 'index1', '1':'index2'})

# %%
df_tactics
# Out:
#                                                            0  \
# formation                                                541
# lineup     [{'player': {'id': 3509, 'name': 'Thibaut Cour...
#
#                                                            1
# formation                                               4231
# lineup     [{'player': {'id': 3175, 'name': 'Eiji Kawashi...

# %%
# dataframe with player_id and when they were subbed off
# time_off = df.loc[(df.type == 'Substitution'),
#                       ['player', 'minute']]
# time_off.rename({'player' : 'player_id', 
#                  'minute': 'off'}, axis='columns', inplace=True)

# %%
# time_off

# %%
# time_on = df.loc[(df.type == 'Substitution'),
#                      ['substitution_replacement', 'minute']].dropna()
# time_on.rename({'substitution_replacement': 'player_id',
#                 'minute': 'on'}, axis='columns', inplace=True)

# %%
# time_on

# %%
# players_on = time_on.player_id

# %%
# players_on

# %%
# result = time_off.append(time_on)
# result

# %%
# parser = Sbopen()
# events, related, freeze, tactics = parser.event(7584)
# # filter the tactics lineup for the starting xi
# starting_ids = df[df.type == 'Starting XI'].id
# starting_xi = df[df.id.isin(starting_ids)]
# starting_players = starting_xi.player_id
# starting_players

# %%
# pitch = Pitch(linewidth=4)
# fig, axs = pitch.grid(nrows=3, ncols=4,  # number of rows/ columns
#                       figheight=25,  # the figure height in inches
#                       bottom=0.025,  # starts 2.5% in from the figure bottom
#                       # grid takes up 83% of the figure height
#                       # I calculated this so most of the figure is pitches
#                       # 1 - (bottom + endnote_height + endnote_space +
#                       # title_height + title_space) - 0.025 [space at top]
#                       grid_height=0.83,
#                       # reduced the amount of the figure height reserved
#                       # for the ax_endnote and ax_title since it is in
#                       # fractions of the figure height and the figure height
#                       # has increased. e.g. now the title_height is
#                       # 8% of the figheight (25).
#                       grid_width=0.95,  # the grid takes up 95% of the figwidth
#                       # 5% of the grid_height is the space between pitches.
#                       space=0.05,
#                       endnote_height=0,
#                       title_height=0)
